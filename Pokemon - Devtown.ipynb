# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
import os

# %%
os.chdir('Documents')

# %%
pokemon=pd.read_csv('pokemon - pokemon.csv')
print(pokemon.shape)
pokemon.head()
# Out:
# (807, 14)
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# ## BarCharts

# %%
sb.countplot(data=pokemon,x='generation_id')
# Out:
# <AxesSubplot:xlabel='generation_id', ylabel='count'>

# %%
base_color=sb.color_palette()[0]
sb.countplot(data=pokemon,x='generation_id',color=base_color)
# Out:
# <AxesSubplot:xlabel='generation_id', ylabel='count'>

# %%
base_color=sb.color_palette()[1]
gen_order=pokemon['generation_id'].value_counts().index
sb.countplot(data=pokemon,x='generation_id',color=base_color,order=gen_order)
# Out:
# <AxesSubplot:xlabel='generation_id', ylabel='count'>

# %% [markdown]
# ## Additional Variations

# %%
base_color=sb.color_palette()[6]
sb.countplot(data=pokemon,x='type_1',color=base_color)
plt.xticks(rotation=100);

# %%
base_color=sb.color_palette()[3]
sb.countplot(data=pokemon,x='type_1',color=base_color)
# Out:
# <AxesSubplot:xlabel='type_1', ylabel='count'>

# %%
base_color=sb.color_palette()[2]
sb.countplot(data=pokemon,y='type_1',color=base_color)
# Out:
# <AxesSubplot:xlabel='count', ylabel='type_1'>

# %% [markdown]
# ## Count Missing Data

# %%
pokemon.isna().sum()
# Out:
# id                   0
# species              0
# generation_id        0
# height               0
# weight               0
# base_experience      0
# type_1               0
# type_2             402
# hp                   0
# attack               0
# defense              0
# speed                0
# special-attack       0
# special-defense      0
# dtype: int64

# %%
na_counts=pokemon.isna().sum()
base_color=sb.color_palette()[0]
sb.barplot(na_counts.index.values,na_counts,color=base_color)
plt.xticks(rotation=90);
# Out:
# C:\Users\ALOK KUMAR SAHOO\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##  PIE Charts

# %%
sorted_counts=pokemon['generation_id'].value_counts()
plt.pie(sorted_counts,labels=sorted_counts.index,startangle=90,counterclock=False);
plt.axis('square');

# %% [markdown]
# ## Additional Variables

# %%
sorted_counts=pokemon['generation_id'].value_counts()
plt.pie(sorted_counts,labels=sorted_counts.index,startangle=90,counterclock=False,wedgeprops={'width':0.4});
plt.axis('square');

# %% [markdown]
# ## Histograms

# %%
plt.hist(data=pokemon,x='speed');

# %%
plt.hist(data=pokemon,x='speed',bins=20);

# %%
bins=np.arange(0,pokemon['speed'].max()+1,5)
plt.hist(data=pokemon,x='speed',bins=20);

# %%
plt.figure(figsize=[10,5])

plt.subplot(1,2,1)
bin_edges=np.arange(0,pokemon['speed'].max()+1,+5)
plt.hist(data=pokemon,x='speed',bins=bin_edges);

plt.subplot(1,2,2)
bin_edges=np.arange(0,pokemon['speed'].max()++1,+1)
plt.hist(data=pokemon,x='speed',bins=bin_edges);

# %% [markdown]
# ## Alternative Approach

# %%
sb.distplot(pokemon['speed']);
# Out:
# C:\Users\ALOK KUMAR SAHOO\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(pokemon['speed'],kde=False);
# Out:
# C:\Users\ALOK KUMAR SAHOO\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
bin_edges=np.arange(0,pokemon['speed'].max()+1,5)
sb.distplot(pokemon['speed'],bins=bin_edges,kde=False,hist_kws={'alpha':1});
